# %% [markdown]
# <a href="https://colab.research.google.com/github/sxs6482/beginning-bioinformatics/blob/main/Copy_of_MAFFT%2Btrimal%2Bvis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Install MAFFT and TrimAl

# %%
#Install MAFFT from built in repo
# !apt-get -qq install mafft
# !mafft --version
# Out:
# v7.505 (2022/Apr/10)

# %%
#Install TrimAl from author's github repo and unzip
# !wget -q https://github.com/inab/trimal/releases/download/v1.5.0/trimAl_Linux_x86-64.zip
# !unzip -q trimAl_Linux_x86-64.zip

#Move trimal to PATH location for easier use then cleanup files we don't need
# !mv trimAl_Linux_x86-64/trimal /usr/local/bin
# !rm trimAl_Linux_x86-64.zip
# !rm -rf trimAl_Linux_x86-64

# %%
# install biopython
# !pip -q install biopython pillow

# %%
#Check installs worked by getting version info
# !mafft --version
# !trimal --version
import Bio
print (Bio.__version__)
# Out:
# v7.505 (2022/Apr/10)
#
# trimAl v1.5.rev0 build[2024-05-27]
#
# 1.88

# %% [markdown]
# #Run MAFFT in auto mode
# * **Assumes you have uploaded the P450.fasta file to this Runtime**
# * MAFFT manual: https://mafft.cbrc.jp/alignment/software/manual/manual.html

# %%
# run mafft in auto mode (let mafft decided the optimal algorithm for given dataset)
# !mafft --auto P450.fasta > P450_aln.fasta
# Out:
# nthread = 0
# nthreadpair = 0
# nthreadtb = 0
# ppenalty_ex = 0
# stacksize: 8192 kb
# rescale = 1
# Gap Penalty = -1.53, +0.00, +0.00
#
#
#
# Making a distance matrix ..
#
# There are 8 ambiguous characters.
#   101 / 129
# done.
#
# Constructing a UPGMA tree (efffree=0) ...
#   120 / 129
# done.
#
# Progressive alignment 1/2...
# STEP   114 / 128  f
# Reallocating..done. *alloclen = 4930
# STEP   128 / 128  f
# done.
#
# Making a distance matrix from msa..
#   100 / 129
# done.
#
# Constructing a UPGMA tree (efffree=1) ...
#   120 / 129
# done.
#
# Progressive alignment 2/2...
# STEP   119 / 128  f
# Reallocating..done. *alloclen = 4275
# STEP   128 / 128  f
# done.
#
# disttbfast (aa) Version 7.505
# alg=A, model=BLOSUM62, 1.53, -0.00, -0.00, noshift, amax=0.0
# 0 thread(s)
#
# rescale = 1
# dndpre (aa) Version 7.505
# alg=X, model=BLOSUM62, 1.53, +0.12, -0.00, noshift, amax=0.0
# 0 thread(s)
#
# minimumweight = 0.000010
# autosubalignment = 0.000000
# nthread = 0
# randomseed = 0
# blosum 62 / kimura 200
# poffset = 0
# niter = 2
# sueff_global = 0.100000
# nadd = 2
# rescale = 1
#
#   120 / 129
# Segment   1/  3    1-2806
# Segment   2/  3 2785-2788
# STEP 002-127-1  identical.
# Converged.
#
# Segment   3/  3 2788-2878
# done
# dvtditr (aa) Version 7.505
# alg=A, model=BLOSUM62, 1.53, -0.00, -0.00, noshift, amax=0.0
# 0 thread(s)
#
#
# Strategy:
#  FFT-NS-i (Standard)
#  Iterative refinement method (max. 2 iterations)
#
# If unsure which option to use, try 'mafft --auto input > output'.
# For more information, see 'mafft --help', 'mafft --man' and the mafft page.
#
# The default gap scoring scheme has been changed in version 7.110 (2013 Oct).
# It tends to insert more gaps into gap-rich regions than previous versions.
# To disable this change, add the --leavegappyregion option.

# %% [markdown]
# # Make a dot plot of the top 16 alignments
# * 16 is arbitrary - (4x4 grid)

# %%
# Import tools
from google.colab import files
import numpy as np
import matplotlib.pyplot as plt
from Bio import AlignIO
from PIL import Image
import os

msa_path = "P450_aln.fasta"   # alignment file already in /content/
msa_format = "fasta"

# ---------- params you can tweak ----------
k = 9                    # k-mer size for dot plots (larger -> cleaner diagonals)
tiles_per_row = 4
tiles_per_col = 4
tile_size_px = (700, 700)   # pixel size of each tile in the final grid
out_dir = "dotplot_tiles"
grid_out = "top16_dotplots_grid.png"
# ------------------------------------------

# Load alignment
aln = AlignIO.read(msa_path, msa_format)
N = len(aln)
ids = [rec.id for rec in aln]
seqs = [str(rec.seq) for rec in aln]
seq_bytes = [np.frombuffer(s.encode("ascii"), dtype="S1") for s in seqs]

# Pairwise identity ignoring gaps (and only comparing aligned positions)
pairs = []
for i in range(N):
    A = seq_bytes[i]
    for j in range(i+1, N):
        B = seq_bytes[j]
        valid = (A != b'-') & (B != b'-')
        denom = int(valid.sum())
        pid = float((A[valid] == B[valid]).sum())/denom if denom else 0.0
        pairs.append((pid, i, j))

# Top 16 pairs
pairs.sort(key=lambda x: x[0], reverse=True)
top_pairs = pairs[:tiles_per_row * tiles_per_col]

# Helper: dot-plot points from UNGAPPED sequences using k-mer matches
def dotplot_points(s1, s2, k):
    s1u = s1.replace('-', '')
    s2u = s2.replace('-', '')
    index = {}
    # index k-mers of s2
    L2 = len(s2u)
    for j in range(L2 - k + 1):
        km = s2u[j:j+k]
        index.setdefault(km, []).append(j)
    xs, ys = [], []
    L1 = len(s1u)
    for i in range(L1 - k + 1):
        km = s1u[i:i+k]
        js = index.get(km)
        if js:
            xs.extend(js)
            ys.extend([i]*len(js))
    return np.array(xs), np.array(ys), s1u, s2u

# Make individual tiles
os.makedirs(out_dir, exist_ok=True)
tile_paths = []
for idx, (pid, i, j) in enumerate(top_pairs, start=1):
    x, y, s1u, s2u = dotplot_points(seqs[i], seqs[j], k)
    fig = plt.figure(figsize=(tile_size_px[0]/100, tile_size_px[1]/100), dpi=100)
    plt.scatter(x, y, s=0.5)   # don't set explicit colors; keep default
    plt.xlabel(ids[j])
    plt.ylabel(ids[i])
    plt.title(f"Pair {idx}: %ID={pid*100:.1f} (k={k})")
    plt.tight_layout()
    out_path = os.path.join(out_dir, f"dotpair_{idx:02d}.png")
    plt.savefig(out_path, bbox_inches="tight")
    plt.close(fig)
    tile_paths.append(out_path)

# Stitch into a 4×4 grid
grid_w = tiles_per_row * tile_size_px[0]
grid_h = tiles_per_col * tile_size_px[1]
grid = Image.new("RGB", (grid_w, grid_h), (255, 255, 255))

for idx, path in enumerate(tile_paths):
    r = idx // tiles_per_row
    c = idx % tiles_per_row
    img = Image.open(path).resize(tile_size_px)
    grid.paste(img, (c*tile_size_px[0], r*tile_size_px[1]))

grid.save(grid_out)
print("Saved grid ->", grid_out)

#Display the graphs
from IPython.display import Image as IPyImage, display
display(IPyImage(filename=grid_out))
from google.colab import files
files.download(grid_out)
# Out:
# Saved grid -> top16_dotplots_grid.png

# %% [markdown]
# # Run TrimAl to automate trimming alignments
# * https://trimal.cgenomics.org/

# %%
# run trimal, output the trimmed sequences and html to visualize conserved sites
# creates P450_trimmed.fasta - for input to new MSA
# !trimal -in P450_aln.fasta -out P450_trimmed.fasta -htmlout trimmed.html -automated1

# %% [markdown]
# #Run MAFFT on trimmed sequences

# %%
# run mafft in auto mode
# !mafft --auto P450_trimmed.fasta > P450_trimmed_aln.fasta
# Out:
# outputhat23=2
# treein = 0
# compacttree = 0
# stacksize: 8192 kb
# rescale = 1
# All-to-all alignment.
# tbfast-pair (aa) Version 7.505
# alg=L, model=BLOSUM62, 2.00, -0.10, +0.10, noshift, amax=0.0
# 0 thread(s)
#
# outputhat23=2
# Loading 'hat3.seed' ...
# done.
# Writing hat3 for iterative refinement
# rescale = 1
# Gap Penalty = -1.53, +0.00, +0.00
# tbutree = 1, compacttree = 0
# Constructing a UPGMA tree ...
#   120 / 129
# done.
#
# Progressive alignment ...
# STEP   128 /128
# done.
# tbfast (aa) Version 7.505
# alg=A, model=BLOSUM62, 1.53, -0.00, -0.00, noshift, amax=0.0
# 1 thread(s)
#
# minimumweight = 0.000010
# autosubalignment = 0.000000
# nthread = 0
# randomseed = 0
# blosum 62 / kimura 200
# poffset = 0
# niter = 2
# sueff_global = 0.100000
# nadd = 2
# Loading 'hat3' ... done.
# rescale = 1
#
#   120 / 129
# Segment   1/  1    1- 448
# done
# dvtditr (aa) Version 7.505
# alg=A, model=BLOSUM62, 1.53, -0.00, -0.00, noshift, amax=0.0
# 0 thread(s)
#
#
# Strategy:
#  L-INS-i (Probably most accurate, very slow)
#  Iterative refinement method (<2) with LOCAL pairwise alignment information
#
# If unsure which option to use, try 'mafft --auto input > output'.
# For more information, see 'mafft --help', 'mafft --man' and the mafft page.
#
# The default gap scoring scheme has been changed in version 7.110 (2013 Oct).
# It tends to insert more gaps into gap-rich regions than previous versions.
# To disable this change, add the --leavegappyregion option.

# %% [markdown]
# # Generate dotplots for new trimmed MSA

# %%
msa_path = "P450_trimmed_aln.fasta"   # trimmed alignment file already in /content/
msa_format = "fasta"

# ---------- params you can tweak ----------
k = 9                    # k-mer size for dot plots (larger -> cleaner diagonals)
tiles_per_row = 4
tiles_per_col = 4
tile_size_px = (700, 700)   # pixel size of each tile in the final grid
out_dir = "dotplot_tiles_trimmed"
grid_out = "top16_dotplots_trimmed_grid.png"
# ------------------------------------------

# Load alignment
aln = AlignIO.read(msa_path, msa_format)
N = len(aln)
ids = [rec.id for rec in aln]
seqs = [str(rec.seq) for rec in aln]
seq_bytes = [np.frombuffer(s.encode("ascii"), dtype="S1") for s in seqs]

# Pairwise identity ignoring gaps (and only comparing aligned positions)
pairs = []
for i in range(N):
    A = seq_bytes[i]
    for j in range(i+1, N):
        B = seq_bytes[j]
        valid = (A != b'-') & (B != b'-')
        denom = int(valid.sum())
        pid = float((A[valid] == B[valid]).sum())/denom if denom else 0.0
        pairs.append((pid, i, j))

# Top 16 pairs
pairs.sort(key=lambda x: x[0], reverse=True)
top_pairs = pairs[:tiles_per_row * tiles_per_col]

# Helper: dot-plot points from UNGAPPED sequences using k-mer matches
def dotplot_points(s1, s2, k):
    s1u = s1.replace('-', '')
    s2u = s2.replace('-', '')
    index = {}
    # index k-mers of s2
    L2 = len(s2u)
    for j in range(L2 - k + 1):
        km = s2u[j:j+k]
        index.setdefault(km, []).append(j)
    xs, ys = [], []
    L1 = len(s1u)
    for i in range(L1 - k + 1):
        km = s1u[i:i+k]
        js = index.get(km)
        if js:
            xs.extend(js)
            ys.extend([i]*len(js))
    return np.array(xs), np.array(ys), s1u, s2u

# Make individual tiles
os.makedirs(out_dir, exist_ok=True)
tile_paths = []
for idx, (pid, i, j) in enumerate(top_pairs, start=1):
    x, y, s1u, s2u = dotplot_points(seqs[i], seqs[j], k)
    fig = plt.figure(figsize=(tile_size_px[0]/100, tile_size_px[1]/100), dpi=100)
    plt.scatter(x, y, s=0.5)   # don't set explicit colors; keep default
    plt.xlabel(ids[j])
    plt.ylabel(ids[i])
    plt.title(f"Pair {idx}: %ID={pid*100:.1f} (k={k})")
    plt.tight_layout()
    out_path = os.path.join(out_dir, f"dotpair_{idx:02d}.png")
    plt.savefig(out_path, bbox_inches="tight")
    plt.close(fig)
    tile_paths.append(out_path)

# Stitch into a 4×4 grid
grid_w = tiles_per_row * tile_size_px[0]
grid_h = tiles_per_col * tile_size_px[1]
grid = Image.new("RGB", (grid_w, grid_h), (255, 255, 255))

for idx, path in enumerate(tile_paths):
    r = idx // tiles_per_row
    c = idx % tiles_per_row
    img = Image.open(path).resize(tile_size_px)
    grid.paste(img, (c*tile_size_px[0], r*tile_size_px[1]))

grid.save(grid_out)
print("Saved grid ->", grid_out)

#Display the graphs
from IPython.display import Image as IPyImage, display
display(IPyImage(filename=grid_out))
from google.colab import files
files.download(grid_out)
# Out:
# Saved grid -> top16_dotplots_trimmed_grid.png

# %% [markdown]
# # Create a gene tree to show relationships among the sequences
# * This code creates a circular layout tree, but that is an aesthetic choice

# %%
import numpy as np
from Bio import AlignIO, Phylo
from Bio.Phylo.TreeConstruction import DistanceTreeConstructor, DistanceMatrix
import math
import matplotlib.pyplot as plt

# Load alignment
aln = AlignIO.read(msa_path, msa_format)
ids = [rec.id for rec in aln]
seqs = [np.frombuffer(str(rec.seq).encode("ascii"), dtype="S1") for rec in aln]
N = len(seqs)
print(f"{N} sequences; alignment length {aln.get_alignment_length()}")

# Fast p-distance: 1 - identity, comparing only positions where both are not gaps ('-')
def pairwise_pdist(A, B):
    valid = (A != b'-') & (B != b'-')
    denom = int(valid.sum())
    if denom == 0:
        return 1.0
    return 1.0 - float((A[valid] == B[valid]).sum()) / denom

# Build lower-triangular distance matrix
dm_mat = [[0.0]*(i+1) for i in range(N)]
for i in range(N):
    for j in range(i):
        dm_mat[i][j] = pairwise_pdist(seqs[i], seqs[j])

dm = DistanceMatrix(names=ids, matrix=dm_mat)

# Neighbor-Joining tree
constructor = DistanceTreeConstructor()
tree = constructor.nj(dm)

# Midpoint root for symmetry
try:
    tree.root_at_midpoint()
except Exception:
    pass

# Save Newick
newick_path = "gene_tree_nj.newick"
Phylo.write(tree, newick_path, "newick")
print("Saved Newick ->", newick_path)

# Compute clade depths (distance from root)
def clade_depths(clade, current=0.0, depths=None):
    if depths is None:
        depths = {}
    depths[clade] = current
    for child in clade.clades:
        bl = child.branch_length or 0.0
        clade_depths(child, current + bl, depths)
    return depths

depths = clade_depths(tree.root)
max_depth = max(depths.values()) or 1.0
def radius_of(clade):
    # map to [0.1, 1.0] for margin
    return 0.1 + 0.9 * (depths[clade] / max_depth)

# Evenly spaced leaf angles
terms = tree.get_terminals()
n_leaves = len(terms)
leaf_to_angle = {t: 2*math.pi * i / n_leaves for i, t in enumerate(terms)}

# Angle of internal nodes = circular mean of child angles
def compute_angles(clade):
    if clade.is_terminal():
        return leaf_to_angle[clade]
    child_angles = [compute_angles(c) for c in clade.clades]
    x = sum(math.cos(a) for a in child_angles) / len(child_angles)
    y = sum(math.sin(a) for a in child_angles) / len(child_angles)
    return math.atan2(y, x) % (2*math.pi)

angles = {}
def assign_angles(clade):
    angles[clade] = compute_angles(clade)
    for c in clade.clades:
        assign_angles(c)
assign_angles(tree.root)

# Draw on polar axes (one chart, no explicit colors)
fig = plt.figure(figsize=(12, 12))
ax = plt.subplot(111, projection="polar")
ax.set_axis_off()
# ----- choose which "level" to color by -----
L = 3  # e.g., root=0, children=1, etc.

# Compute topological levels (edge-count from root)
def clade_levels(clade, level=0, out=None):
    if out is None: out = {}
    out[clade] = level
    for ch in clade.clades:
        clade_levels(ch, level+1, out)
    return out

levels = clade_levels(tree.root)

# Anchor nodes at level L
anchors = [c for c, lv in levels.items() if lv == L]

# Assign colors and paint entire subtrees below each anchor
cmap = plt.get_cmap("tab10")
edge_colors = {}                         # (parent, child) -> color
anchor_color = {}                        # node at level L -> color

def paint_subtree(node, color):
    for ch in node.clades:
        edge_colors[(node, ch)] = color
        paint_subtree(ch, color)

for i, a in enumerate(anchors):
    col = cmap(i % 10)
    anchor_color[a] = col
    paint_subtree(a, col)

# (optional) make leaves’ label text match their subtree color
anchor_set = set(anchors)
def color_of_leaf(leaf):
    # path from root to leaf; first anchor we encounter decides color
    path = [tree.root] + tree.get_path(leaf)
    for n in path:
        if n in anchor_set:
            return anchor_color[n]
    return "0.5"


def draw_branch(parent, child):
    rp, rc = radius_of(parent), radius_of(child)
    ap, ac = angles[parent], angles[child]
    da = (ac - ap + math.pi) % (2*math.pi) - math.pi
    th = np.linspace(ap, ap + da, 24)

    col = edge_colors.get((parent, child), "0.5")
    ax.plot([ap, ap], [rp, rc], linewidth=0.7, color=col)
    ax.plot(th, np.full_like(th, rc), linewidth=0.7, color=col)

    # shortest arc to child angle at child radius
    da = (ac - ap + math.pi) % (2*math.pi) - math.pi
    th = np.linspace(ap, ap + da, 24)
    ax.plot(th, np.full_like(th, rc), linewidth=0.7)

for parent in tree.find_clades(order="level"):
    for child in parent.clades:
        draw_branch(parent, child)

# Leaf labels
label_r = 1.03
for t in terms:
    a = angles[t]
    ax.text(a, label_r, t.name, fontsize=6,
            rotation=np.degrees(a), rotation_mode="anchor",
            ha="left" if 0 <= a <= math.pi else "right",
            va="center",
            color=color_of_leaf(t))

plt.title("Neighbor-Joining gene tree (circular, p-distance)", pad=20)
png_path = "gene_tree_circular.png"
plt.savefig(png_path, dpi=300, bbox_inches="tight")
plt.show()
print("Saved PNG ->", png_path)
# Out:
# 129 sequences; alignment length 2871
# Saved Newick -> gene_tree_nj.newick
# Saved PNG -> gene_tree_circular.png

# %%
from Bio import AlignIO

muscle_file = "P450_best_alignment.fasta"
mafft_file = "P450_aln.fasta"

muscle = AlignIO.read(muscle_file, "fasta")
mafft = AlignIO.read(mafft_file, "fasta")

print("=" * 70)
print("MUSCLE vs MAFFT ALIGNMENT COMPARISON")
print("=" * 70)

print("\nNumber of sequences:")
print("MUSCLE:", len(muscle))
print("MAFFT :", len(mafft))

print("\nAlignment length:")
print("MUSCLE:", muscle.get_alignment_length())
print("MAFFT :", mafft.get_alignment_length())

# Check IDs
muscle_ids = [r.id for r in muscle]
mafft_ids = [r.id for r in mafft]

print("\nSame sequence IDs:", set(muscle_ids) == set(mafft_ids))

# ---------------------------------------------------------
# Compare ungapped sequences
# ---------------------------------------------------------

print("\n" + "=" * 70)
print("UNGAPPED SEQUENCE CHECK")
print("=" * 70)

all_same = True

for record in muscle:

    seq_id = record.id

    seq_muscle = str(record.seq).replace("-", "")
    seq_mafft = str(
        next(r for r in mafft if r.id == seq_id).seq
    ).replace("-", "")

    if seq_muscle != seq_mafft:
        print("Different ungapped sequence:", seq_id)
        all_same = False

if all_same:
    print("All 129 ungapped sequences are identical.")

# ---------------------------------------------------------
# Gap statistics
# ---------------------------------------------------------

print("\n" + "=" * 70)
print("ALIGNMENT LENGTH")
print("=" * 70)

if muscle.get_alignment_length() != mafft.get_alignment_length():

    print("MUSCLE and MAFFT have DIFFERENT alignment lengths.")
    print("\nThis means their columns cannot be compared directly.")

else:

    print("MUSCLE and MAFFT have the SAME alignment length.")

    length = muscle.get_alignment_length()

    identical_columns = 0
    different_columns = 0

    gap_only_columns = 0
    residue_columns = 0

    for i in range(length):

        col_muscle = muscle[:, i]
        col_mafft = mafft[:, i]

        if col_muscle == col_mafft:

            identical_columns += 1

        else:

            different_columns += 1

            # Determine whether difference is only gap placement
            gap_only = True

            for a, b in zip(col_muscle, col_mafft):

                if a != b:

                    if a != "-" and b != "-":
                        gap_only = False
                        break

            if gap_only:
                gap_only_columns += 1
            else:
                residue_columns += 1

    print("\nTotal columns:", length)
    print("Identical columns:", identical_columns)
    print("Different columns:", different_columns)
    print("Gap-placement differences:", gap_only_columns)
    print("Residue differences:", residue_columns)

    print(
        "\nPercent identical columns:",
        round(100 * identical_columns / length, 2),
        "%"
    )

# ---------------------------------------------------------
# Per-sequence alignment length and gap count
# ---------------------------------------------------------

print("\n" + "=" * 70)
print("PER-SEQUENCE GAP COMPARISON")
print("=" * 70)

results = []

for m in muscle:

    seq_id = m.id

    a = str(m.seq)

    mafft_record = next(
        r for r in mafft if r.id == seq_id
    )

    b = str(mafft_record.seq)

    muscle_gaps = a.count("-")
    mafft_gaps = b.count("-")

    results.append(
        (seq_id, len(a), muscle_gaps, mafft_gaps)
    )

for seq_id, length, mg, ag in results:

    if mg != ag:

        print(
            f"{seq_id}\t"
            f"MUSCLE gaps={mg}\t"
            f"MAFFT gaps={ag}"
        )

print("\nComparison complete.")
# Out:
# ======================================================================
# MUSCLE vs MAFFT ALIGNMENT COMPARISON
# ======================================================================
#
# Number of sequences:
# MUSCLE: 129
# MAFFT : 129
#
# Alignment length:
# MUSCLE: 4132
# MAFFT : 2871
#
# Same sequence IDs: True
#
# ======================================================================
# UNGAPPED SEQUENCE CHECK
# ======================================================================
# All 129 ungapped sequences are identical.
#
# ======================================================================
# ALIGNMENT LENGTH
# ======================================================================
# MUSCLE and MAFFT have DIFFERENT alignment lengths.
#
# This means their columns cannot be compared directly.
#
# ======================================================================
# PER-SEQUENCE GAP COMPARISON
# ======================================================================
# gi|270009225|gb|EFA05673.1|	MUSCLE gaps=3645	MAFFT gaps=2384
# gi|270015110|gb|EFA11558.1|	MUSCLE gaps=3597	MAFFT gaps=2336
# gi|270004883|gb|EFA01331.1|	MUSCLE gaps=3667	MAFFT gaps=2406
# gi|270006416|gb|EFA02864.1|	MUSCLE gaps=3550	MAFFT gaps=2289
# gi|270001275|gb|EEZ97722.1|	MUSCLE gaps=3644	MAFFT gaps=2383
# gi|270008247|gb|EFA04695.1|	MUSCLE gaps=3622	MAFFT gaps=2361
# gi|270011133|gb|EFA07581.1|	MUSCLE gaps=3597	MAFFT gaps=2336
# gi|270011073|gb|EFA07521.1|	MUSCLE gaps=3593	MAFFT gaps=2332
# gi|270006359|gb|EFA02807.1|	MUSCLE gaps=3619	MAFFT gaps=2358
# gi|270006458|gb|EFA02906.1|	MUSCLE gaps=3610	MAFFT gaps=2349
# gi|270002749|gb|EEZ99196.1|	MUSCLE gaps=3631	MAFFT gaps=2370
# gi|270004813|gb|EFA01261.1|	MUSCLE gaps=3639	MAFFT gaps=2378
# gi|270004816|gb|EFA01264.1|	MUSCLE gaps=3640	MAFFT gaps=2379
# gi|270004817|gb|EFA01265.1|	MUSCLE gaps=3639	MAFFT gaps=2378
# gi|270014217|gb|EFA10665.1|	MUSCLE gaps=3651	MAFFT gaps=2390
# gi|270014221|gb|EFA10669.1|	MUSCLE gaps=3605	MAFFT gaps=2344
# gi|270008221|gb|EFA04669.1|	MUSCLE gaps=3667	MAFFT gaps=2406
# gi|270011125|gb|EFA07573.1|	MUSCLE gaps=3704	MAFFT gaps=2443
# gi|270016408|gb|EFA12854.1|	MUSCLE gaps=3635	MAFFT gaps=2374
# gi|270016410|gb|EFA12856.1|	MUSCLE gaps=3627	MAFFT gaps=2366
# gi|270016411|gb|EFA12857.1|	MUSCLE gaps=3627	MAFFT gaps=2366
# gi|270016084|gb|EFA12532.1|	MUSCLE gaps=3640	MAFFT gaps=2379
# gi|270009265|gb|EFA05713.1|	MUSCLE gaps=3638	MAFFT gaps=2377
# gi|270016409|gb|EFA12855.1|	MUSCLE gaps=3626	MAFFT gaps=2365
# gi|270009236|gb|EFA05684.1|	MUSCLE gaps=3661	MAFFT gaps=2400
# gi|270008229|gb|EFA04677.1|	MUSCLE gaps=3639	MAFFT gaps=2378
# gi|270008228|gb|EFA04676.1|	MUSCLE gaps=3629	MAFFT gaps=2368
# gi|270008230|gb|EFA04678.1|	MUSCLE gaps=3629	MAFFT gaps=2368
# gi|270008157|gb|EFA04605.1|	MUSCLE gaps=3635	MAFFT gaps=2374
# gi|270008226|gb|EFA04674.1|	MUSCLE gaps=3630	MAFFT gaps=2369
# gi|270009282|gb|EFA05730.1|	MUSCLE gaps=3647	MAFFT gaps=2386
# gi|270016191|gb|EFA12639.1|	MUSCLE gaps=3641	MAFFT gaps=2380
# gi|270016189|gb|EFA12637.1|	MUSCLE gaps=3644	MAFFT gaps=2383
# gi|270016183|gb|EFA12631.1|	MUSCLE gaps=3642	MAFFT gaps=2381
# gi|270016190|gb|EFA12638.1|	MUSCLE gaps=3657	MAFFT gaps=2396
# gi|270002891|gb|EEZ99338.1|	MUSCLE gaps=3614	MAFFT gaps=2353
# gi|270002796|gb|EEZ99243.1|	MUSCLE gaps=3618	MAFFT gaps=2357
# gi|270009285|gb|EFA05733.1|	MUSCLE gaps=3690	MAFFT gaps=2429
# gi|270009235|gb|EFA05683.1|	MUSCLE gaps=3629	MAFFT gaps=2368
# gi|270009245|gb|EFA05693.1|	MUSCLE gaps=3636	MAFFT gaps=2375
# gi|270016081|gb|EFA12529.1|	MUSCLE gaps=3641	MAFFT gaps=2380
# gi|270016184|gb|EFA12632.1|	MUSCLE gaps=3639	MAFFT gaps=2378
# gi|270006374|gb|EFA02822.1|	MUSCLE gaps=3616	MAFFT gaps=2355
# gi|270006373|gb|EFA02821.1|	MUSCLE gaps=3613	MAFFT gaps=2352
# gi|270006368|gb|EFA02816.1|	MUSCLE gaps=3619	MAFFT gaps=2358
# gi|296495590|gb|ADH29767.1|	MUSCLE gaps=3611	MAFFT gaps=2350
# gi|270006371|gb|EFA02819.1|	MUSCLE gaps=3613	MAFFT gaps=2352
# gi|270006376|gb|EFA02824.1|	MUSCLE gaps=3612	MAFFT gaps=2351
# gi|270006375|gb|EFA02823.1|	MUSCLE gaps=3612	MAFFT gaps=2351
# gi|270006372|gb|EFA02820.1|	MUSCLE gaps=3612	MAFFT gaps=2351
# gi|270006369|gb|EFA02817.1|	MUSCLE gaps=3612	MAFFT gaps=2351
# gi|270006370|gb|EFA02818.1|	MUSCLE gaps=3612	MAFFT gaps=2351
# gi|270006377|gb|EFA02825.1|	MUSCLE gaps=3611	MAFFT gaps=2350
# gi|270016182|gb|EFA12630.1|	MUSCLE gaps=3635	MAFFT gaps=2374
# gi|270016186|gb|EFA12634.1|	MUSCLE gaps=3625	MAFFT gaps=2364
# gi|270016187|gb|EFA12635.1|	MUSCLE gaps=3626	MAFFT gaps=2365
# gi|270016185|gb|EFA12633.1|	MUSCLE gaps=3873	MAFFT gaps=2612
# gi|270016188|gb|EFA12636.1|	MUSCLE gaps=3620	MAFFT gaps=2359
# gi|270009283|gb|EFA05731.1|	MUSCLE gaps=3644	MAFFT gaps=2383
# gi|270016179|gb|EFA12627.1|	MUSCLE gaps=3635	MAFFT gaps=2374
# gi|270016180|gb|EFA12628.1|	MUSCLE gaps=3633	MAFFT gaps=2372
# gi|270001240|gb|EEZ97687.1|	MUSCLE gaps=2742	MAFFT gaps=1481
# gi|189241724|ref|XP_001809620.1|	MUSCLE gaps=3642	MAFFT gaps=2381
# gi|270008116|gb|EFA04564.1|	MUSCLE gaps=3612	MAFFT gaps=2351
# gi|270012703|gb|EFA09151.1|	MUSCLE gaps=3652	MAFFT gaps=2391
# gi|270004794|gb|EFA01242.1|	MUSCLE gaps=3600	MAFFT gaps=2339
# gi|270012701|gb|EFA09149.1|	MUSCLE gaps=3655	MAFFT gaps=2394
# gi|270012702|gb|EFA09150.1|	MUSCLE gaps=3625	MAFFT gaps=2364
# gi|189240531|ref|XP_972348.2|	MUSCLE gaps=3627	MAFFT gaps=2366
# gi|270012828|gb|EFA09276.1|	MUSCLE gaps=3635	MAFFT gaps=2374
# gi|270012795|gb|EFA09243.1|	MUSCLE gaps=3629	MAFFT gaps=2368
# gi|270002740|gb|EEZ99187.1|	MUSCLE gaps=3598	MAFFT gaps=2337
# gi|270011345|gb|EFA07793.1|	MUSCLE gaps=3167	MAFFT gaps=1906
# gi|270011356|gb|EFA07804.1|	MUSCLE gaps=3321	MAFFT gaps=2060
# gi|270012695|gb|EFA09143.1|	MUSCLE gaps=3669	MAFFT gaps=2408
# gi|189240567|ref|XP_001815543.1|	MUSCLE gaps=3616	MAFFT gaps=2355
# gi|270012693|gb|EFA09141.1|	MUSCLE gaps=3609	MAFFT gaps=2348
# gi|189240561|ref|XP_973646.2|	MUSCLE gaps=3753	MAFFT gaps=2492
# gi|270012694|gb|EFA09142.1|	MUSCLE gaps=3608	MAFFT gaps=2347
# gi|270012791|gb|EFA09239.1|	MUSCLE gaps=3635	MAFFT gaps=2374
# gi|270012793|gb|EFA09241.1|	MUSCLE gaps=3628	MAFFT gaps=2367
# gi|270012792|gb|EFA09240.1|	MUSCLE gaps=3601	MAFFT gaps=2340
# gi|270012794|gb|EFA09242.1|	MUSCLE gaps=3602	MAFFT gaps=2341
# gi|270012700|gb|EFA09148.1|	MUSCLE gaps=3602	MAFFT gaps=2341
# gi|270012827|gb|EFA09275.1|	MUSCLE gaps=3606	MAFFT gaps=2345
# gi|270012830|gb|EFA09278.1|	MUSCLE gaps=3648	MAFFT gaps=2387
# gi|270004875|gb|EFA01323.1|	MUSCLE gaps=3631	MAFFT gaps=2370
# gi|270004874|gb|EFA01322.1|	MUSCLE gaps=3656	MAFFT gaps=2395
# gi|194473702|ref|NP_001123994.1|	MUSCLE gaps=3640	MAFFT gaps=2379
# gi|270008180|gb|EFA04628.1|	MUSCLE gaps=3651	MAFFT gaps=2390
# gi|270008181|gb|EFA04629.1|	MUSCLE gaps=3645	MAFFT gaps=2384
# gi|270004824|gb|EFA01272.1|	MUSCLE gaps=3631	MAFFT gaps=2370
# gi|270008087|gb|EFA04535.1|	MUSCLE gaps=3629	MAFFT gaps=2368
# gi|270008169|gb|EFA04617.1|	MUSCLE gaps=3640	MAFFT gaps=2379
# gi|270008168|gb|EFA04616.1|	MUSCLE gaps=3633	MAFFT gaps=2372
# gi|194473697|ref|NP_001123993.1|	MUSCLE gaps=3626	MAFFT gaps=2365
# gi|270012831|gb|EFA09279.1|	MUSCLE gaps=3634	MAFFT gaps=2373
# gi|270008167|gb|EFA04615.1|	MUSCLE gaps=3633	MAFFT gaps=2372
# gi|282721123|ref|NP_001164235.1|	MUSCLE gaps=3628	MAFFT gaps=2367
# gi|270011040|gb|EFA07488.1|	MUSCLE gaps=3621	MAFFT gaps=2360
# gi|167466280|ref|NP_001107860.1|	MUSCLE gaps=3579	MAFFT gaps=2318
# gi|33113213|gb|AAP94193.1|	MUSCLE gaps=3641	MAFFT gaps=2380
# gi|270014333|gb|EFA10781.1|	MUSCLE gaps=3636	MAFFT gaps=2375
# gi|167003806|ref|NP_001107791.1|	MUSCLE gaps=3572	MAFFT gaps=2311
# gi|270014309|gb|EFA10757.1|	MUSCLE gaps=3639	MAFFT gaps=2378
# gi|33113212|gb|AAP94192.1|	MUSCLE gaps=3627	MAFFT gaps=2366
# gi|270014307|gb|EFA10755.1|	MUSCLE gaps=3627	MAFFT gaps=2366
# gi|189241028|ref|XP_970987.2|	MUSCLE gaps=3805	MAFFT gaps=2544
# gi|270014303|gb|EFA10751.1|	MUSCLE gaps=3659	MAFFT gaps=2398
# gi|270014305|gb|EFA10753.1|	MUSCLE gaps=3628	MAFFT gaps=2367
# gi|270014304|gb|EFA10752.1|	MUSCLE gaps=3629	MAFFT gaps=2368
# gi|270014306|gb|EFA10754.1|	MUSCLE gaps=3629	MAFFT gaps=2368
# gi|270008720|gb|EFA05168.1|	MUSCLE gaps=3318	MAFFT gaps=2057
# gi|270009263|gb|EFA05711.1|	MUSCLE gaps=3644	MAFFT gaps=2383
# gi|270002916|gb|EEZ99363.1|	MUSCLE gaps=3969	MAFFT gaps=2708
# gi|270002917|gb|EEZ99364.1|	MUSCLE gaps=3637	MAFFT gaps=2376
# gi|270004417|gb|EFA00865.1|	MUSCLE gaps=3360	MAFFT gaps=2099
# gi|270001269|gb|EEZ97716.1|	MUSCLE gaps=3637	MAFFT gaps=2376
# gi|270009269|gb|EFA05717.1|	MUSCLE gaps=3665	MAFFT gaps=2404
# gi|189238170|ref|XP_973400.2|	MUSCLE gaps=2858	MAFFT gaps=1597
# gi|270009258|gb|EFA05706.1|	MUSCLE gaps=3640	MAFFT gaps=2379
# gi|270006475|gb|EFA02923.1|	MUSCLE gaps=3633	MAFFT gaps=2372
# gi|270009257|gb|EFA05705.1|	MUSCLE gaps=3631	MAFFT gaps=2370
# gi|270009259|gb|EFA05707.1|	MUSCLE gaps=3637	MAFFT gaps=2376
# gi|270009260|gb|EFA05708.1|	MUSCLE gaps=3644	MAFFT gaps=2383
# gi|270008719|gb|EFA05167.1|	MUSCLE gaps=3211	MAFFT gaps=1950
# gi|270009255|gb|EFA05703.1|	MUSCLE gaps=3637	MAFFT gaps=2376
# gi|270009256|gb|EFA05704.1|	MUSCLE gaps=3630	MAFFT gaps=2369
# gi|270009261|gb|EFA05709.1|	MUSCLE gaps=3641	MAFFT gaps=2380
#
# Comparison complete.
